# %%
import sys
import os
import numpy as np
import pickle
import pandas as pd
import seaborn as sns
import sklearn
import scipy
import matplotlib.pyplot as plt
import itertools
import qinfer as qi
from lfig import LatexFigure

sys.path.append("/home/bf16951/QMD")
import qmla

# %matplotlib inline

# %%
scipy.special.comb(20, 2)
# Out:
# 190.0

# %%
run_path = "Dec_03/21_17"
results = qmla.load_results(
    results_folder = "/home/bf16951/bc_results/",
    results_time = "Sep_21/16_22",
    instance_id = 10
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-b3c9b4fe5824> in <module>()
#       3     results_folder = "/home/bf16951/bc_results/",
#       4     results_time = "Sep_21/16_22",
# ----> 5     instance_id = 10
#       6 )
#
# ~/QMD/qmla/load_results.py in load_results(results_time, results_folder_elements, results_folder, instance_id)
#      51     plot_probes = pickle.load(open(os.path.join(results_dir, 'plot_probes.p'), 'rb'))
#      52     true_measurements = pickle.load(open(os.path.join(results_dir, 'system_measurements.p'), 'rb'))
# ---> 53     q = pickle.load(open(qmla_class_file, 'rb'))
#      54     try:
#      55         q2 = pickle.load(open(os.path.join(results_dir, 'qmd_class_002.p'), 'rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/bf16951/bc_results/Sep_21/16_22/qmla_class_010.p'

# %%
results.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a238dd3b274e> in <module>()
# ----> 1 results.keys()
#
# NameError: name 'results' is not defined

# %%
q = results['qmla_instance']

# %%
es = q.exploration_class

# %%
ga = es.genetic_algorithm

# %%
es.fitness_method
# Out:
# 'f_score'

# %%
q.model_database
# Out:
#      branch_id branches_present_on  f_score  \
# 0          1.0                 [1]     0.50
# 1          1.0                 [1]     0.46
# 2          1.0                 [1]     0.53
# 3          1.0              [1, 2]     0.50
# 4          1.0                 [1]     0.00
# 5          1.0                 [1]     0.36
# 6          1.0                 [1]     0.00
# 7          1.0                 [1]     0.50
# 8          1.0                 [1]     0.40
# 9          1.0                 [1]     0.31
# 10         1.0                 [1]     0.37
# 11         1.0                 [1]     0.31
# 12         1.0           [1, 2, 3]     0.57
# 13         1.0                 [1]     0.29
# 14         1.0                 [1]     0.37
# 15         1.0                 [1]     0.37
# 16         1.0                 [1]     0.50
# 17         1.0                 [1]     0.27
# 18         1.0                 [1]     0.42
# 19         1.0                 [1]     0.15
# 20         1.0              [1, 2]     0.57
# 21         1.0                 [1]     0.00
# 22         1.0                 [1]     0.53
# 23         1.0              [1, 2]     0.57
# 24         1.0                 [1]     0.29
# 25         1.0                 [1]     0.33
# 26         1.0                 [1]     0.33
# 27         1.0                 [1]     0.27
# 28         2.0              [2, 3]     0.59
# 29         2.0                 [2]     0.57
# ..         ...                 ...      ...
# 104        5.0              [5, 7]     0.77
# 105        5.0              [5, 6]     0.77
# 106        5.0              [5, 7]     0.77
# 107        5.0           [5, 6, 7]     0.83
# 108        5.0                 [5]     0.71
# 109        5.0                 [5]     0.77
# 110        5.0           [5, 6, 7]     0.83
# 111        6.0              [6, 7]     0.77
# 112        6.0                 [6]     0.77
# 113        6.0              [6, 7]     0.77
# 114        6.0              [6, 7]     0.83
# 115        6.0                 [6]     0.77
# 116        6.0                 [6]     0.77
# 117        6.0                 [6]     0.77
# 118        6.0                 [6]     0.77
# 119        6.0                 [6]     0.73
# 120        6.0              [6, 7]     0.77
# 121        6.0                 [6]     0.77
# 122        6.0              [6, 7]     0.83
# 123        6.0                 [6]     0.77
# 124        6.0                 [6]     0.77
# 125        7.0                 [7]     0.77
# 126        7.0                 [7]     0.77
# 127        7.0                 [7]     0.77
# 128        7.0                 [7]     0.71
# 129        7.0                 [7]     0.77
# 130        7.0                 [7]     0.77
# 131        7.0                 [7]     0.77
# 132        7.0                 [7]     0.77
# 133        7.0                 [7]     0.71
#
#                                             latex_name  \
# 0    $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{y}\sigma...
# 1    $\sigma_{(1, 2)}^{z}\sigma_{(1, 3)}^{x}\sigma_...
# 2    $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{yz}\sig...
# 3    $\sigma_{(1, 2)}^{y}\sigma_{(2, 3)}^{z}\sigma_...
# 4    $\sigma_{(1, 3)}^{y}\sigma_{(1, 4)}^{xy}\sigma...
# 5    $\sigma_{(1, 3)}^{yz}\sigma_{(2, 3)}^{yz}\sigm...
# 6    $\sigma_{(1, 2)}^{x}\sigma_{(1, 4)}^{xz}\sigma...
# 7    $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{xyz}\sig...
# 8    $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{xyz}\si...
# 9    $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{y}\sigm...
# 10   $\sigma_{(1, 2)}^{xy}\sigma_{(1, 3)}^{yz}\sigm...
# 11   $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{x}\sigm...
# 12   $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 13   $\sigma_{(1, 4)}^{yz}\sigma_{(2, 3)}^{xy}\sigm...
# 14   $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{x}\sigm...
# 15   $\sigma_{(1, 2)}^{x}\sigma_{(1, 3)}^{xyz}\sigm...
# 16   $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{yz}\sigm...
# 17   $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{y}\sigm...
# 18   $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{xy}\sig...
# 19   $\sigma_{(1, 2)}^{xy}\sigma_{(1, 3)}^{x}\sigma...
# 20   $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 21   $\sigma_{(1, 2)}^{y}\sigma_{(1, 3)}^{xy}\sigma...
# 22   $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{xz}\sigm...
# 23   $\sigma_{(1, 2)}^{xz}\sigma_{(1, 3)}^{xz}\sigm...
# 24   $\sigma_{(1, 2)}^{z}\sigma_{(1, 3)}^{xy}\sigma...
# 25   $\sigma_{(1, 2)}^{xy}\sigma_{(1, 3)}^{yz}\sigm...
# 26   $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{x}\sigma...
# 27   $\sigma_{(1, 2)}^{xy}\sigma_{(1, 3)}^{y}\sigma...
# 28   $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 29   $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# ..                                                 ...
# 104  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{xz}\sigm...
# 105  $\sigma_{(1, 2)}^{xz}\sigma_{(1, 3)}^{xz}\sigm...
# 106  $\sigma_{(1, 2)}^{xz}\sigma_{(1, 3)}^{xz}\sigm...
# 107  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{yz}\sigm...
# 108  $\sigma_{(1, 2)}^{xz}\sigma_{(1, 3)}^{xz}\sigm...
# 109  $\sigma_{(1, 2)}^{xz}\sigma_{(1, 3)}^{xz}\sigm...
# 110  $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{z}\sigm...
# 111  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{yz}\sigm...
# 112  $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{z}\sigm...
# 113  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{yz}\sigm...
# 114  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 115  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 116  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 117  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{yz}\sigm...
# 118  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 119  $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{z}\sigm...
# 120  $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{z}\sigm...
# 121  $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{z}\sigm...
# 122  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 123  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{yz}\sigm...
# 124  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 125  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 126  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{xz}\sigm...
# 127  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{xz}\sigm...
# 128  $\sigma_{(1, 2)}^{xz}\sigma_{(1, 3)}^{xz}\sigm...
# 129  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{z}\sigma...
# 130  $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{z}\sigm...
# 131  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{yz}\sigm...
# 132  $\sigma_{(1, 2)}^{yz}\sigma_{(1, 3)}^{xz}\sigm...
# 133  $\sigma_{(1, 2)}^{xyz}\sigma_{(1, 3)}^{xz}\sig...
#
#                                            latex_terms  model_id  \
# 0    [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...       1.0
# 1    [$\sigma_{(1, 2)}^{z}$, $\sigma_{(1, 3)}^{x}$,...       2.0
# 2    [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...       3.0
# 3    [$\sigma_{(1, 2)}^{y}$, $\sigma_{(2, 3)}^{z}$,...       4.0
# 4    [$\sigma_{(1, 3)}^{y}$, $\sigma_{(1, 4)}^{x}$,...       5.0
# 5    [$\sigma_{(1, 3)}^{y}$, $\sigma_{(1, 3)}^{z}$,...       6.0
# 6    [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 4)}^{x}$,...       7.0
# 7    [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...       8.0
# 8    [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...       9.0
# 9    [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      10.0
# 10   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      11.0
# 11   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      12.0
# 12   [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...      13.0
# 13   [$\sigma_{(1, 4)}^{y}$, $\sigma_{(1, 4)}^{z}$,...      14.0
# 14   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      15.0
# 15   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 3)}^{x}$,...      16.0
# 16   [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...      17.0
# 17   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      18.0
# 18   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      19.0
# 19   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      20.0
# 20   [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...      21.0
# 21   [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 3)}^{x}$,...      22.0
# 22   [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...      23.0
# 23   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{z}$,...      24.0
# 24   [$\sigma_{(1, 2)}^{z}$, $\sigma_{(1, 3)}^{x}$,...      25.0
# 25   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      26.0
# 26   [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...      27.0
# 27   [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...      28.0
# 28   [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...      29.0
# 29   [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...      30.0
# ..                                                 ...       ...
# 104  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     105.0
# 105  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{z}$,...     106.0
# 106  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{z}$,...     107.0
# 107  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     108.0
# 108  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{z}$,...     109.0
# 109  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{z}$,...     110.0
# 110  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...     111.0
# 111  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     112.0
# 112  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...     113.0
# 113  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     114.0
# 114  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     115.0
# 115  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     116.0
# 116  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     117.0
# 117  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     118.0
# 118  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     119.0
# 119  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...     120.0
# 120  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...     121.0
# 121  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...     122.0
# 122  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     123.0
# 123  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     124.0
# 124  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     125.0
# 125  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     126.0
# 126  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     127.0
# 127  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     128.0
# 128  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{z}$,...     129.0
# 129  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     130.0
# 130  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...     131.0
# 131  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     132.0
# 132  [$\sigma_{(1, 2)}^{y}$, $\sigma_{(1, 2)}^{z}$,...     133.0
# 133  [$\sigma_{(1, 2)}^{x}$, $\sigma_{(1, 2)}^{y}$,...     134.0
#
#                                             model_name  \
# 0    pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 1    pauliSet_1J2_zJz_d4+pauliSet_1J3_xJx_d4+pauliS...
# 2    pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 3    pauliSet_1J2_yJy_d4+pauliSet_2J3_zJz_d4+pauliS...
# 4    pauliSet_1J3_yJy_d4+pauliSet_1J4_xJx_d4+pauliS...
# 5    pauliSet_1J3_yJy_d4+pauliSet_1J3_zJz_d4+pauliS...
# 6    pauliSet_1J2_xJx_d4+pauliSet_1J4_xJx_d4+pauliS...
# 7    pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 8    pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 9    pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 10   pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 11   pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 12   pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 13   pauliSet_1J4_yJy_d4+pauliSet_1J4_zJz_d4+pauliS...
# 14   pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 15   pauliSet_1J2_xJx_d4+pauliSet_1J3_xJx_d4+pauliS...
# 16   pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 17   pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 18   pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 19   pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 20   pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 21   pauliSet_1J2_yJy_d4+pauliSet_1J3_xJx_d4+pauliS...
# 22   pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 23   pauliSet_1J2_xJx_d4+pauliSet_1J2_zJz_d4+pauliS...
# 24   pauliSet_1J2_zJz_d4+pauliSet_1J3_xJx_d4+pauliS...
# 25   pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 26   pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 27   pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 28   pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 29   pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# ..                                                 ...
# 104  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 105  pauliSet_1J2_xJx_d4+pauliSet_1J2_zJz_d4+pauliS...
# 106  pauliSet_1J2_xJx_d4+pauliSet_1J2_zJz_d4+pauliS...
# 107  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 108  pauliSet_1J2_xJx_d4+pauliSet_1J2_zJz_d4+pauliS...
# 109  pauliSet_1J2_xJx_d4+pauliSet_1J2_zJz_d4+pauliS...
# 110  pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 111  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 112  pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 113  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 114  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 115  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 116  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 117  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 118  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 119  pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 120  pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 121  pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 122  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 123  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 124  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 125  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 126  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 127  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 128  pauliSet_1J2_xJx_d4+pauliSet_1J2_zJz_d4+pauliS...
# 129  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 130  pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
# 131  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 132  pauliSet_1J2_yJy_d4+pauliSet_1J2_zJz_d4+pauliS...
# 133  pauliSet_1J2_xJx_d4+pauliSet_1J2_yJy_d4+pauliS...
#
#                                 model_storage_instance  \
# 0    <qmla.model_for_storage.ModelInstanceForStorag...
# 1    <qmla.model_for_storage.ModelInstanceForStorag...
# 2    <qmla.model_for_storage.ModelInstanceForStorag...
# 3    <qmla.model_for_storage.ModelInstanceForStorag...
# 4    <qmla.model_for_storage.ModelInstanceForStorag...
# 5    <qmla.model_for_storage.ModelInstanceForStorag...
# 6    <qmla.model_for_storage.ModelInstanceForStorag...
# 7    <qmla.model_for_storage.ModelInstanceForStorag...
# 8    <qmla.model_for_storage.ModelInstanceForStorag...
# 9    <qmla.model_for_storage.ModelInstanceForStorag...
# 10   <qmla.model_for_storage.ModelInstanceForStorag...
# 11   <qmla.model_for_storage.ModelInstanceForStorag...
# 12   <qmla.model_for_storage.ModelInstanceForStorag...
# 13   <qmla.model_for_storage.ModelInstanceForStorag...
# 14   <qmla.model_for_storage.ModelInstanceForStorag...
# 15   <qmla.model_for_storage.ModelInstanceForStorag...
# 16   <qmla.model_for_storage.ModelInstanceForStorag...
# 17   <qmla.model_for_storage.ModelInstanceForStorag...
# 18   <qmla.model_for_storage.ModelInstanceForStorag...
# 19   <qmla.model_for_storage.ModelInstanceForStorag...
# 20   <qmla.model_for_storage.ModelInstanceForStorag...
# 21   <qmla.model_for_storage.ModelInstanceForStorag...
# 22   <qmla.model_for_storage.ModelInstanceForStorag...
# 23   <qmla.model_for_storage.ModelInstanceForStorag...
# 24   <qmla.model_for_storage.ModelInstanceForStorag...
# 25   <qmla.model_for_storage.ModelInstanceForStorag...
# 26   <qmla.model_for_storage.ModelInstanceForStorag...
# 27   <qmla.model_for_storage.ModelInstanceForStorag...
# 28   <qmla.model_for_storage.ModelInstanceForStorag...
# 29   <qmla.model_for_storage.ModelInstanceForStorag...
# ..                                                 ...
# 104  <qmla.model_for_storage.ModelInstanceForStorag...
# 105  <qmla.model_for_storage.ModelInstanceForStorag...
# 106  <qmla.model_for_storage.ModelInstanceForStorag...
# 107  <qmla.model_for_storage.ModelInstanceForStorag...
# 108  <qmla.model_for_storage.ModelInstanceForStorag...
# 109  <qmla.model_for_storage.ModelInstanceForStorag...
# 110  <qmla.model_for_storage.ModelInstanceForStorag...
# 111  <qmla.model_for_storage.ModelInstanceForStorag...
# 112  <qmla.model_for_storage.ModelInstanceForStorag...
# 113  <qmla.model_for_storage.ModelInstanceForStorag...
# 114  <qmla.model_for_storage.ModelInstanceForStorag...
# 115  <qmla.model_for_storage.ModelInstanceForStorag...
# 116  <qmla.model_for_storage.ModelInstanceForStorag...
# 117  <qmla.model_for_storage.ModelInstanceForStorag...
# 118  <qmla.model_for_storage.ModelInstanceForStorag...
# 119  <qmla.model_for_storage.ModelInstanceForStorag...
# 120  <qmla.model_for_storage.ModelInstanceForStorag...
# 121  <qmla.model_for_storage.ModelInstanceForStorag...
# 122  <qmla.model_for_storage.ModelInstanceForStorag...
# 123  <qmla.model_for_storage.ModelInstanceForStorag...
# 124  <qmla.model_for_storage.ModelInstanceForStorag...
# 125  <qmla.model_for_storage.ModelInstanceForStorag...
# 126  <qmla.model_for_storage.ModelInstanceForStorag...
# 127  <qmla.model_for_storage.ModelInstanceForStorag...
# 128  <qmla.model_for_storage.ModelInstanceForStorag...
# 129  <qmla.model_for_storage.ModelInstanceForStorag...
# 130  <qmla.model_for_storage.ModelInstanceForStorag...
# 131  <qmla.model_for_storage.ModelInstanceForStorag...
# 132  <qmla.model_for_storage.ModelInstanceForStorag...
# 133  <qmla.model_for_storage.ModelInstanceForStorag...
#
#                                                  terms
# 0    [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 1    [pauliSet_1J2_zJz_d4, pauliSet_1J3_xJx_d4, pau...
# 2    [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 3    [pauliSet_1J2_yJy_d4, pauliSet_2J3_zJz_d4, pau...
# 4    [pauliSet_1J3_yJy_d4, pauliSet_1J4_xJx_d4, pau...
# 5    [pauliSet_1J3_yJy_d4, pauliSet_1J3_zJz_d4, pau...
# 6    [pauliSet_1J2_xJx_d4, pauliSet_1J4_xJx_d4, pau...
# 7    [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 8    [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 9    [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 10   [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 11   [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 12   [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 13   [pauliSet_1J4_yJy_d4, pauliSet_1J4_zJz_d4, pau...
# 14   [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 15   [pauliSet_1J2_xJx_d4, pauliSet_1J3_xJx_d4, pau...
# 16   [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 17   [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 18   [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 19   [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 20   [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 21   [pauliSet_1J2_yJy_d4, pauliSet_1J3_xJx_d4, pau...
# 22   [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 23   [pauliSet_1J2_xJx_d4, pauliSet_1J2_zJz_d4, pau...
# 24   [pauliSet_1J2_zJz_d4, pauliSet_1J3_xJx_d4, pau...
# 25   [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 26   [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 27   [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 28   [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 29   [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# ..                                                 ...
# 104  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 105  [pauliSet_1J2_xJx_d4, pauliSet_1J2_zJz_d4, pau...
# 106  [pauliSet_1J2_xJx_d4, pauliSet_1J2_zJz_d4, pau...
# 107  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 108  [pauliSet_1J2_xJx_d4, pauliSet_1J2_zJz_d4, pau...
# 109  [pauliSet_1J2_xJx_d4, pauliSet_1J2_zJz_d4, pau...
# 110  [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 111  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 112  [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 113  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 114  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 115  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 116  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 117  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 118  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 119  [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 120  [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 121  [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 122  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 123  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 124  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 125  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 126  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 127  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 128  [pauliSet_1J2_xJx_d4, pauliSet_1J2_zJz_d4, pau...
# 129  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 130  [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
# 131  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 132  [pauliSet_1J2_yJy_d4, pauliSet_1J2_zJz_d4, pau...
# 133  [pauliSet_1J2_xJx_d4, pauliSet_1J2_yJy_d4, pau...
#
# [134 rows x 9 columns]

# %%
a = {'this' : 1, 'that' : 4}

# %%
len(a)
# Out:
# 2

# %%
"+".join(terms)
# Out:
# '1+1+4+1'
